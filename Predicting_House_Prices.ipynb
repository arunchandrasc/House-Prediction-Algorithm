# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load some house data sales

# %%
#sales=graphlab.SFrame('home_data.gl')
import sys
print(sys.version)
# Out:
# 2.7.14 |Anaconda, Inc.| (default, Dec  7 2017, 11:07:58)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
housing_data=pd.read_csv('/Users/megatropics/Dropbox/arun_suvy_python/kc_house_train_data.csv');

# %%
housing_data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
train_housing.shape
# Out:
# (17384, 21)

# %%
housing_data
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12     6054650070  20141007T000000   400000.0         3       1.75
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(housing_data.sqft_living,housing_data.price)

# %% [markdown]
# Create a Simple Regression model of sqft living to price

# %%
train_data=housing_data.sample(frac=0.8);
#train_data=np.random.rand()
test_data=housing_data.sample(frac=0.2);

# %%
from sklearn import linear_model

# %%
sqft_model=linear_model.LinearRegression()

# %%
sqft_model.fit(housing_data.
               .reshape(-1,1),housing_data.price)
# Out:
#   File "<ipython-input-70-0a80b221ea85>", line 2
#     .reshape(-1,1),housing_data.price)
#     ^
# SyntaxError: invalid syntax

# %%
sqft_model.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-449a07587503> in <module>()
# ----> 1 sqft_model.fit()
#
# TypeError: fit() takes at least 3 arguments (1 given)
